# %% [markdown]
# # Project 1 - Infrastructure AI Assistant
#
# For this first project, we'll work on one of the very common use cases for Gen AI: a chatbot

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display
import gradio as gr

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# For our chatbot we will select GPT-4.1-nano due to the price efficiency

MODEL = "gpt-4.1-mini"
openai = OpenAI()

# %% [markdown]
# ## Our first Assistant conversation
#
# We can call the API with a conversation - a list of dictionaries representing each interaction:
#
# ```
# [
#     {"role": "system", "content": "essential instructions here, including tone"},
#     {"role": "user", "content": "a question from the user"},
#     {"role": "assistant": "content": "a response"},
#     ...
# ]
# ```

# %%
system_message = "You are a helpful assistant for an Azure Cloud Infrastructure Engineer Team. "
system_message += "Your job is to explain infrastructure-as-code concepts clearly, assist with writing and troubleshooting Terraform modules"
system_message += "Be concise, technically accurate, and use practical examples provided in the context wherever possible."

# %% [markdown]
# And now we wrap this in a simple chat() function,
# and then we use the shockingly simple Gradio platform to bring up a Chatbot UI.
#
# First, the chat function, which takes the current message and the history of prior messages:

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=MODEL, messages=messages)
    return response.choices[0].message.content

# %%
# And look how complicated it is to launch a User Interface, with the fabulous gradio platform

gr.ChatInterface(fn=chat, type="messages").launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Expertise
#
# We can give our model knowledge using the system prompt

# %%
system_message += " In case it's relevant, use first the knowledge provided and the exmaples formthe markdown files. The department name is Axso Terraform Self Service"

# %%
system_message
# Out:
# "You are a helpful assistant for an Azure Cloud Infrastructure Engineer Team. Your job is to explain infrastructure-as-code concepts clearly, assist with writing and troubleshooting Terraform modulesBe concise, technically accurate, and use practical examples provided in the context wherever possible. In case it's relevant, use first the knowledge provided and the exmaples formthe markdown files. In case it's relevant, use first the knowledge provided and the exmaples formthe markdown files. The department name is Axso Terraform Self Service"

# %%
gr.ChatInterface(fn=chat, type="messages").launch(inbrowser=True)

# %% [markdown]
# ## First steps towards agentic workflows
#
# Having multiple AIs collaborate to solve the problem is a simple step. Let's add another AI to the mix!
#
# Let's pick a fun one: adding multi-modality..

# %%
import base64
from io import BytesIO
from PIL import Image

def artist_agent(tool):
    image_response = openai.images.generate(
            model="dall-e-3",
            prompt=f"An image representing a cloud infrastructure team using {tool}, in a vibrant pop-art style",
            size="1024x1024",
            n=1,
            response_format="b64_json",
        )
    image_base64 = image_response.data[0].b64_json
    image_data = base64.b64decode(image_base64)
    return Image.open(BytesIO(image_data))

# %%
image = artist_agent("Terraform")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %% [markdown]
# ## Bringing it all together in a mini Agent Framework
#
# Bringing together both our LLM calls in 1 UI

# %%
def chat(history):
    message = history[-1]["content"]
    messages = [{"role": "system", "content": system_message}] + history
    response = openai.chat.completions.create(model=MODEL, messages=messages)
    image =  artist_agent("Terraform") if 'Terraform' in message.lower() else None
    reply = response.choices[0].message.content
    history += [{"role":"assistant", "content":reply}]
    return history, image

# %%
# More involved Gradio code as we're not using the preset Chat interface!

with gr.Blocks() as ui:
    with gr.Row():
        chatbot = gr.Chatbot(height=400, type="messages")
        image_output = gr.Image(height=400)
    with gr.Row():
        entry = gr.Textbox(label="Chat with our AI Assistant:")

    def do_entry(message, history):
        history += [{"role": "user", "content": message}]
        return "", history

    entry.submit(do_entry, inputs=[entry, chatbot], outputs=[entry, chatbot]).then(
        chat, inputs=chatbot, outputs=[chatbot, image_output]
    )

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Congratulations!
#
# You just created a multi-modal AI Assistant
#
# ### Simple Assignment
#
# Based on this code:
#
# ```python
# ticket_prices = {"london": "$799", "paris": "$899", "tokyo": "$1400", "sydney": "$2999"}
# ```
#
# Allow the Chatbot to quote ticket prices for any of those destinations, and show images!
#
# ## MAJOR ASSIGNMENT
#
# Make a variation of this Chatbot that applies this to your business
#
#
# ### Optional Stretch Assignment for office hours
#
# Research "tool use" (also known as Function Calling) and then use this technique to add Tool capabilities to your LLM to look up ticket prices..

# %%
ticket_prices = {"london": "$799", "paris": "$899", "tokyo": "$1400", "sydney": "$2999"}
